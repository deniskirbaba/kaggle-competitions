# %% [markdown]
# # Problem
#
# This is the regression task, the evaluation metric is the RMSE between the logarithm of the predicted value and the logarithm of the observed sales price. (Taking logs means that errors in predicting expensive houses and cheap houses will affect the result equally.)

# %%
import numpy as np
import pandas as pd

# %%
train_dataset = pd.read_csv('/content/train.csv')
train_dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
X = train_dataset.loc[:, train_dataset.columns.drop('SalePrice')]
Y = train_dataset.loc[:, 'SalePrice']
X.shape, Y.shape
# Out:
# ((1460, 80), (1460,))

# %%
numerical_features_ids = np.where(X.dtypes != 'object')[0]
categorical_features_ids = np.where(X.dtypes == 'object')[0]
len(numerical_features_ids), len(categorical_features_ids)
# Out:
# (37, 43)

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2)
X_train.shape, X_val.shape, Y_train.shape, Y_val.shape
# Out:
# ((1168, 80), (292, 80), (1168,), (292,))

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class CustomTransformer(BaseEstimator, TransformerMixin):

    def fit(self, X, y=None):
        return self

    def transform(self, X: pd.DataFrame):
        numerical_features_mask = X.dtypes != 'object'
        X.loc[:, numerical_features_mask].fillna(value=-999, inplace=True)
        X.loc[:, ~numerical_features_mask].fillna(value='-999', inplace=True)
        return X

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

preprocessing_pipeline = Pipeline(steps=[
    ('imputer', CustomTransformer()),
    ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

# %%
X_train = preprocessing_pipeline.fit_transform(X_train)
X_val = preprocessing_pipeline.transform(X_val)
# Out:
# <ipython-input-41-7150e3e7301d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, numerical_features_mask].fillna(value=-999, inplace=True)
# <ipython-input-41-7150e3e7301d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, ~numerical_features_mask].fillna(value='-999', inplace=True)
# <ipython-input-41-7150e3e7301d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, numerical_features_mask].fillna(value=-999, inplace=True)
# <ipython-input-41-7150e3e7301d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, ~numerical_features_mask].fillna(value='-999', inplace=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 3, 4, 9, 19, 22, 23, 24, 26, 34, 36, 37, 38, 43, 44, 45, 46, 59, 62, 66, 67, 68, 69, 70, 71, 74, 75] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
def mean_squared_error(
    y_true,
    y_pred,
    *,
    sample_weight=None,
    multioutput="uniform_average",
    squared="deprecated",
):

    output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)

    if isinstance(multioutput, str):
        if multioutput == "raw_values":
            return output_errors
        elif multioutput == "uniform_average":
            # pass None as weights to np.average: uniform mean
            multioutput = None

    return np.average(output_errors, weights=multioutput)

# %%
def root_mean_squared_error(
    y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
):

    output_errors = np.sqrt(
        mean_squared_error(
            y_true, y_pred, sample_weight=sample_weight, multioutput="raw_values"
        )
    )

    if isinstance(multioutput, str):
        if multioutput == "raw_values":
            return output_errors
        elif multioutput == "uniform_average":
            # pass None as weights to np.average: uniform mean
            multioutput = None

    return np.average(output_errors, weights=multioutput)

# %%
def root_mean_squared_log_error(
    y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
):

    if (y_true < 0).any() or (y_pred < 0).any():
        raise ValueError(
            "Root Mean Squared Logarithmic Error cannot be used when "
            "targets contain negative values."
        )

    return root_mean_squared_error(
        np.log1p(y_true),
        np.log1p(y_pred),
        sample_weight=sample_weight,
        multioutput=multioutput,
    )

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

cv_params = {'n_estimators': [100, 250, 500],
             'max_depth': [10, 25, 50],
             'min_samples_leaf': [1, 10, 20]}
cv_reg = GridSearchCV(estimator=RandomForestRegressor(),
                      param_grid=cv_params,
                      scoring=make_scorer(root_mean_squared_log_error, greater_is_better=False),
                      verbose=2,
                      cv=5)

# %%
cv_reg.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=100; total time=   7.5s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=100; total time=   6.4s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=100; total time=   7.7s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=100; total time=   6.3s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=100; total time=   7.3s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=250; total time=  16.9s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=250; total time=  17.8s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=250; total time=  17.4s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=250; total time=  16.8s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=250; total time=  17.7s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=500; total time=  34.2s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=500; total time=  35.5s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=500; total time=  35.2s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=500; total time=  33.5s
# [CV] END .max_depth=10, min_samples_leaf=1, n_estimators=500; total time=  34.6s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=250; total time=   8.0s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=250; total time=   6.9s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=250; total time=   8.0s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=250; total time=   7.4s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=250; total time=   7.6s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=500; total time=  15.2s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=500; total time=  15.0s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=500; total time=  15.9s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=500; total time=  15.0s
# [CV] END max_depth=10, min_samples_leaf=10, n_estimators=500; total time=  16.0s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=250; total time=   4.9s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=250; total time=   5.9s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=250; total time=   4.8s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=250; total time=   5.8s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=250; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=500; total time=  10.7s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=500; total time=  10.7s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   9.8s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=500; total time=  10.8s
# [CV] END max_depth=10, min_samples_leaf=20, n_estimators=500; total time=  10.8s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=100; total time=  13.8s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=100; total time=  13.8s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=100; total time=  13.8s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=100; total time=  13.8s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=100; total time=  13.9s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=250; total time=  35.1s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=250; total time=  34.8s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=250; total time=  35.4s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=250; total time=  34.4s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=250; total time=  35.0s
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=25, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=100; total time=   3.2s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=250; total time=   8.0s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=250; total time=   7.3s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=250; total time=   8.0s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=250; total time=   8.1s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=250; total time=   8.2s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=500; total time=  15.3s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=500; total time=  15.1s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=500; total time=  16.3s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=500; total time=  15.2s
# [CV] END max_depth=25, min_samples_leaf=10, n_estimators=500; total time=  15.2s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=100; total time=   1.9s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=100; total time=   2.3s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=100; total time=   2.8s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=250; total time=   4.9s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=250; total time=   6.0s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=250; total time=   4.9s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=250; total time=   5.2s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=250; total time=   5.9s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=500; total time=  11.0s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=500; total time=  10.5s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=500; total time=  10.1s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=500; total time=  10.8s
# [CV] END max_depth=25, min_samples_leaf=20, n_estimators=500; total time=  10.8s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=100; total time=  14.1s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=100; total time=  13.9s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=100; total time=  13.8s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=100; total time=  13.9s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=100; total time=  15.5s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=250; total time=  35.0s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=250; total time=  35.3s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=250; total time=  35.0s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=250; total time=  34.3s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=250; total time=  35.4s
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END .max_depth=50, min_samples_leaf=1, n_estimators=500; total time= 1.2min
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   3.8s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   2.8s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   2.9s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=250; total time=   7.5s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=250; total time=   8.1s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=250; total time=   7.1s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=250; total time=   8.3s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=250; total time=   7.7s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=500; total time=  15.8s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=500; total time=  15.3s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=500; total time=  15.3s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=500; total time=  15.3s
# [CV] END max_depth=50, min_samples_leaf=10, n_estimators=500; total time=  15.6s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   2.7s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   2.1s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   2.0s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=250; total time=   5.9s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=250; total time=   4.8s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=250; total time=   5.7s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=250; total time=   5.1s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=250; total time=   4.9s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=500; total time=  10.8s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=500; total time=  11.2s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=500; total time=  11.9s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=500; total time=  10.9s
# [CV] END max_depth=50, min_samples_leaf=20, n_estimators=500; total time=  10.8s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [10, 25, 50],
#                          'min_samples_leaf': [1, 10, 20],
#                          'n_estimators': [100, 250, 500]},
#              scoring=make_scorer(root_mean_squared_log_error, greater_is_better=False),
#              verbose=2)

# %%
cv_reg.best_estimator_
# Out:
# RandomForestRegressor(max_depth=25, n_estimators=250)

# %%
cv_reg.score(X_val, Y_val)
# Out:
# -0.16418320145516244

# %%
X = preprocessing_pipeline.fit_transform(X)
# Out:
# <ipython-input-41-7150e3e7301d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, numerical_features_mask].fillna(value=-999, inplace=True)
# <ipython-input-41-7150e3e7301d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, ~numerical_features_mask].fillna(value='-999', inplace=True)

# %%
final_est = cv_reg.best_estimator_

# %%
final_est.fit(X, Y)
# Out:
# RandomForestRegressor(max_depth=25, n_estimators=250)

# %%
test_dataset = pd.read_csv('/content/test.csv')
X_test = test_dataset.copy()
X_test = preprocessing_pipeline.transform(X_test)
# Out:
# <ipython-input-41-7150e3e7301d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, numerical_features_mask].fillna(value=-999, inplace=True)
# <ipython-input-41-7150e3e7301d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, ~numerical_features_mask].fillna(value='-999', inplace=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1, 2, 3, 4, 9, 19, 23, 24, 26, 34, 36, 37, 38, 43, 44, 45, 46, 47, 48, 49, 53, 54, 55, 56, 59, 61, 62, 66, 67, 68, 69, 70, 71, 75, 78] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
submission = pd.DataFrame()
submission['Id'] = test_dataset.loc[:, 'Id']
submission['SalePrice'] = cv_reg.predict(X_test)

# %%
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  116148.053127
# 1  1462  148852.965099
# 2  1463  175452.007573
# 3  1464  185225.015311
# 4  1465  206113.159451

# %%
submission.to_csv('/content/rfc.csv', index=False)
